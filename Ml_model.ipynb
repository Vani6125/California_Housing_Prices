# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
x=data.drop(['median_house_value'],axis=1)
y=data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
y_test
# Out:
# 18708     75600.0
# 5919     137100.0
# 15242    439900.0
# 3996     271300.0
# 11429    265100.0
#            ...
# 15134    155700.0
# 8446     294800.0
# 1829     186900.0
# 16605    256700.0
# 16200     54600.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
train_data=x_train.join(y_train)

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13047    -121.28     38.55                35.0       7088.0          1279.0
# 9289     -122.51     38.06                24.0       9493.0          1935.0
# 5577     -118.30     33.84                37.0       1241.0           226.0
# 15418    -117.25     33.22                26.0       2010.0           347.0
# 13988    -117.15     34.83                30.0       5370.0          1062.0
# ...          ...       ...                 ...          ...             ...
# 11686    -117.99     33.88                15.0       2298.0           567.0
# 14754    -117.05     32.56                17.0        985.0           233.0
# 10136    -117.89     33.92                34.0       1473.0           312.0
# 12518    -121.46     38.55                52.0       3126.0           648.0
# 11965    -117.42     34.02                 9.0       5455.0           882.0
#
#        population  households  median_income ocean_proximity
# 13047      4885.0      1272.0         2.6981          INLAND
# 9289       5162.0      1880.0         3.0742        NEAR BAY
# 5577        621.0       255.0         4.9196       <1H OCEAN
# 15418      1160.0       331.0         3.9815       <1H OCEAN
# 13988      2778.0       944.0         3.0990          INLAND
# ...           ...         ...            ...             ...
# 11686      1261.0       527.0         4.2422       <1H OCEAN
# 14754       811.0       223.0         2.8750      NEAR OCEAN
# 10136      1025.0       315.0         3.8333       <1H OCEAN
# 12518      1789.0       558.0         1.7616          INLAND
# 11965      3015.0       858.0         4.2321          INLAND
#
# [16346 rows x 9 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr(numeric_only=True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924798           -0.105297     0.042729
# latitude            -0.924798  1.000000            0.009626    -0.035073
# housing_median_age  -0.105297  0.009626            1.000000    -0.360722
# total_rooms          0.042729 -0.035073           -0.360722     1.000000
# total_bedrooms       0.067200 -0.065747           -0.318528     0.929568
# population           0.098653 -0.107302           -0.295185     0.857004
# households           0.054284 -0.070389           -0.301459     0.919193
# median_income       -0.016856 -0.079235           -0.122693     0.195993
# median_house_value  -0.045415 -0.144787            0.102695     0.132121
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.067200    0.098653    0.054284      -0.016856
# latitude                 -0.065747   -0.107302   -0.070389      -0.079235
# housing_median_age       -0.318528   -0.295185   -0.301459      -0.122693
# total_rooms               0.929568    0.857004    0.919193       0.195993
# total_bedrooms            1.000000    0.875578    0.980659      -0.008982
# population                0.875578    1.000000    0.904199       0.005454
# households                0.980659    0.904199    1.000000       0.011890
# median_income            -0.008982    0.005454    0.011890       1.000000
# median_house_value        0.049408   -0.026606    0.063900       0.691028
#
#                     median_house_value
# longitude                    -0.045415
# latitude                     -0.144787
# housing_median_age            0.102695
# total_rooms                   0.132121
# total_bedrooms                0.049408
# population                   -0.026606
# households                    0.063900
# median_income                 0.691028
# median_house_value            1.000000

# %%
plt.figsize=(15,8)
sns.heatmap(train_data.corr(numeric_only=True),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7241
# INLAND        5220
# NEAR OCEAN    2073
# NEAR BAY      1808
# ISLAND           4
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 13047      False    True   False     False       False
# 9289       False   False   False      True       False
# 5577        True   False   False     False       False
# 15418       True   False   False     False       False
# 13988      False    True   False     False       False
# ...          ...     ...     ...       ...         ...
# 11686       True   False   False     False       False
# 14754      False   False   False     False        True
# 10136       True   False   False     False       False
# 12518      False    True   False     False       False
# 11965      False    True   False     False       False
#
# [16346 rows x 5 columns]

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13047    -121.28     38.55                35.0     8.866300        7.154615
# 9289     -122.51     38.06                24.0     9.158415        7.568379
# 5577     -118.30     33.84                37.0     7.124478        5.424950
# 15418    -117.25     33.22                26.0     7.606387        5.852202
# 13988    -117.15     34.83                30.0     8.588769        6.968850
# ...          ...       ...                 ...          ...             ...
# 11686    -117.99     33.88                15.0     7.740230        6.342121
# 14754    -117.05     32.56                17.0     6.893656        5.455321
# 10136    -117.89     33.92                34.0     7.295735        5.746203
# 12518    -121.46     38.55                52.0     8.047829        6.475433
# 11965    -117.42     34.02                 9.0     8.604471        6.783325
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 13047    8.494129    7.149132         2.6981            112500.0      False
# 9289     8.549273    7.539559         3.0742            118800.0      False
# 5577     6.432940    5.545177         4.9196            232400.0       True
# 15418    7.057037    5.805135         3.9815            142600.0       True
# 13988    7.929846    6.851185         3.0990             66800.0      False
# ...           ...         ...            ...                 ...        ...
# 11686    7.140453    6.269096         4.2422            159400.0       True
# 14754    6.699500    5.411646         2.8750            134500.0      False
# 10136    6.933423    5.755742         3.8333            170400.0       True
# 12518    7.489971    6.326149         1.7616             84100.0      False
# 11965    8.011687    6.755769         4.2321            162800.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 13047    True   False     False       False
# 9289    False   False      True       False
# 5577    False   False     False       False
# 15418   False   False     False       False
# 13988    True   False     False       False
# ...       ...     ...       ...         ...
# 11686   False   False     False       False
# 14754   False   False     False        True
# 10136   False   False     False       False
# 12518    True   False     False       False
# 11965    True   False     False       False
#
# [16346 rows x 14 columns]

# %%
#train_data=train_data.drop(['ocean_proximity'],axis=1)

# %%
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924798           -0.105297     0.026404
# latitude            -0.924798  1.000000            0.009626    -0.028850
# housing_median_age  -0.105297  0.009626            1.000000    -0.313991
# total_rooms          0.026404 -0.028850           -0.313991     1.000000
# total_bedrooms       0.057373 -0.064596           -0.271208     0.945591
# population           0.108570 -0.134706           -0.243565     0.863889
# households           0.053024 -0.085141           -0.240824     0.931802
# median_income       -0.016856 -0.079235           -0.122693     0.207929
# median_house_value  -0.045415 -0.144787            0.102695     0.156164
# <1H OCEAN            0.322788 -0.449619            0.042384     0.019630
# INLAND              -0.053902  0.349532           -0.235134    -0.014219
# ISLAND               0.009524 -0.016727            0.014128    -0.005688
# NEAR BAY            -0.472225  0.356280            0.252785    -0.012217
# NEAR OCEAN           0.038319 -0.153561            0.027241     0.002401
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.057373    0.108570    0.053024      -0.016856
# latitude                 -0.064596   -0.134706   -0.085141      -0.079235
# housing_median_age       -0.271208   -0.243565   -0.240824      -0.122693
# total_rooms               0.945591    0.863889    0.931802       0.207929
# total_bedrooms            1.000000    0.896035    0.974911      -0.024068
# population                0.896035    1.000000    0.930663      -0.001027
# households                0.974911    0.930663    1.000000       0.005316
# median_income            -0.024068   -0.001027    0.005316       1.000000
# median_house_value        0.050704   -0.024359    0.069875       0.691028
# <1H OCEAN                 0.039328    0.113053    0.070108       0.174268
# INLAND                   -0.045692   -0.071661   -0.087442      -0.242298
# ISLAND                    0.000178   -0.009757   -0.006663      -0.009304
# NEAR BAY                 -0.010687   -0.055028   -0.000705       0.054501
# NEAR OCEAN                0.015374   -0.016034    0.018834       0.028400
#
#                     median_house_value  <1H OCEAN    INLAND    ISLAND  \
# longitude                    -0.045415   0.322788 -0.053902  0.009524
# latitude                     -0.144787  -0.449619  0.349532 -0.016727
# housing_median_age            0.102695   0.042384 -0.235134  0.014128
# total_rooms                   0.156164   0.019630 -0.014219 -0.005688
# total_bedrooms                0.050704   0.039328 -0.045692  0.000178
# population                   -0.024359   0.113053 -0.071661 -0.009757
# households                    0.069875   0.070108 -0.087442 -0.006663
# median_income                 0.691028   0.174268 -0.242298 -0.009304
# median_house_value            1.000000   0.261489 -0.487585  0.021064
# <1H OCEAN                     0.261489   1.000000 -0.610837 -0.013952
# INLAND                       -0.487585  -0.610837  1.000000 -0.010716
# ISLAND                        0.021064  -0.013952 -0.010716  1.000000
# NEAR BAY                      0.159677  -0.314490 -0.241553 -0.005517
# NEAR OCEAN                    0.141298  -0.339861 -0.261040 -0.005962
#
#                     NEAR BAY  NEAR OCEAN
# longitude          -0.472225    0.038319
# latitude            0.356280   -0.153561
# housing_median_age  0.252785    0.027241
# total_rooms        -0.012217    0.002401
# total_bedrooms     -0.010687    0.015374
# population         -0.055028   -0.016034
# households         -0.000705    0.018834
# median_income       0.054501    0.028400
# median_house_value  0.159677    0.141298
# <1H OCEAN          -0.314490   -0.339861
# INLAND             -0.241553   -0.261040
# ISLAND             -0.005517   -0.005962
# NEAR BAY            1.000000   -0.134397
# NEAR OCEAN         -0.134397    1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio']=train_data['total_bedrooms']/train_data['total_rooms']
train_data['household_rooms']=train_data['total_rooms']/train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train,y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
x_train_s=scaler.fit_transform(x_train)
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#test_data=test_data.drop(['bedroom_ratio','household_rooms'],axis=1)

# %%
#test_data

# %%
#x_test,y_test=test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
#x_test

# %%
test_data=x_test.join(y_test)

test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(train_data['population']+1)
test_data['households']=np.log(test_data['households']+1)


test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)


test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms']=test_data['total_rooms']/test_data['households']

# %%
x_test,y_test=test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18708    -122.41     40.58                35.0     7.636752        5.955837
# 5919     -118.44     34.28                38.0     7.053586        5.723585
# 15242    -117.25     32.99                10.0     8.502486        6.620073
# 3996     -118.59     34.18                 7.0     9.380421        7.898040
# 11429    -117.97     33.67                25.0     8.270525        6.493754
# ...          ...       ...                 ...          ...             ...
# 15134    -116.92     32.82                17.0     7.821242        6.204558
# 8446     -118.37     33.90                35.0     7.409742        5.598422
# 1829     -122.32     37.92                22.0     7.021084        5.398163
# 16605    -120.67     35.63                 8.0     7.897668        6.018593
# 16200    -121.27     37.95                52.0     7.184629        5.733341
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 18708         NaN    5.929589         2.8512      False    True   False
# 5919          NaN    5.669881         2.5147       True   False   False
# 15242         NaN    6.453625         7.4720      False   False   False
# 3996          NaN    7.803027         4.2009       True   False   False
# 11429         NaN    6.434547         5.6765       True   False   False
# ...           ...         ...            ...        ...     ...     ...
# 15134         NaN    6.086775         2.8875       True   False   False
# 8446          NaN    5.533389         5.6482       True   False   False
# 1829          NaN    5.298317         3.3594      False   False   False
# 16605         NaN    5.945421         4.2841       True   False   False
# 16200         NaN    5.739793         1.8261      False    True   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 18708     False       False       0.779891         1.287906
# 5919      False       False       0.811443         1.244045
# 15242     False        True       0.778604         1.317474
# 3996      False       False       0.841971         1.202152
# 11429     False       False       0.785168         1.285331
# ...         ...         ...            ...              ...
# 15134     False       False       0.793296         1.284957
# 8446      False       False       0.755549         1.339096
# 1829       True       False       0.768850         1.325154
# 16605     False       False       0.762072         1.328362
# 16200     False       False       0.798001         1.251723
#
# [4087 rows x 15 columns]

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13047    -121.28     38.55                35.0     8.866300        7.154615
# 9289     -122.51     38.06                24.0     9.158415        7.568379
# 5577     -118.30     33.84                37.0     7.124478        5.424950
# 15418    -117.25     33.22                26.0     7.606387        5.852202
# 13988    -117.15     34.83                30.0     8.588769        6.968850
# ...          ...       ...                 ...          ...             ...
# 11686    -117.99     33.88                15.0     7.740230        6.342121
# 14754    -117.05     32.56                17.0     6.893656        5.455321
# 10136    -117.89     33.92                34.0     7.295735        5.746203
# 12518    -121.46     38.55                52.0     8.047829        6.475433
# 11965    -117.42     34.02                 9.0     8.604471        6.783325
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 13047    8.494129    7.149132         2.6981      False    True   False
# 9289     8.549273    7.539559         3.0742      False   False   False
# 5577     6.432940    5.545177         4.9196       True   False   False
# 15418    7.057037    5.805135         3.9815       True   False   False
# 13988    7.929846    6.851185         3.0990      False    True   False
# ...           ...         ...            ...        ...     ...     ...
# 11686    7.140453    6.269096         4.2422       True   False   False
# 14754    6.699500    5.411646         2.8750      False   False   False
# 10136    6.933423    5.755742         3.8333       True   False   False
# 12518    7.489971    6.326149         1.7616      False    True   False
# 11965    8.011687    6.755769         4.2321      False    True   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 13047     False       False       0.806945         1.240193
# 9289       True       False       0.826385         1.214715
# 5577      False       False       0.761452         1.284806
# 15418     False       False       0.769380         1.310286
# 13988     False       False       0.811391         1.253618
# ...         ...         ...            ...              ...
# 11686     False       False       0.819371         1.234664
# 14754     False        True       0.791354         1.273856
# 10136     False       False       0.787611         1.267558
# 12518     False       False       0.804619         1.272153
# 11965     False       False       0.788349         1.273648
#
# [16346 rows x 15 columns]

# %%
x_test_s=scaler.transform(x_test)

# %%
x_test=pd.DataFrame.fillna(0,inplace=True)
reg.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 x_test=pd.DataFrame.fillna(value=0,inplace=True)
#       2 reg.score(x_test,y_test)
#
# TypeError: NDFrame.fillna() missing 1 required positional argument: 'self'

# %%
reg.score(x_test_s,y_test)
# Out:
# C:\Users\vanim\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 reg.score(x_test_s,y_test)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:848, in RegressorMixin.score(self, X, y, sample_weight)
#     806 """Return the coefficient of determination of the prediction.
#     807
#     808 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     843 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     844 """
#     846 from .metrics import r2_score
# --> 848 y_pred = self.predict(X)
#     849 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:1064, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1058     raise ValueError(
#    1059         "Found array with dim %d. %s expected <= 2."
#    1060         % (array.ndim, estimator_name)
#    1061     )
#    1063 if force_all_finite:
# -> 1064     _assert_all_finite(
#    1065         array,
#    1066         input_name=input_name,
#    1067         estimator_name=estimator_name,
#    1068         allow_nan=force_all_finite == "allow-nan",
#    1069     )
#    1071 if copy:
#    1072     if _is_numpy_namespace(xp):
#    1073         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:123, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     120 if first_pass_isfinite:
#     121     return
# --> 123 _assert_all_finite_element_wise(
#     124     X,
#     125     xp=xp,
#     126     allow_nan=allow_nan,
#     127     msg_dtype=msg_dtype,
#     128     estimator_name=estimator_name,
#     129     input_name=input_name,
#     130 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:172, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     155 if estimator_name and input_name == "X" and has_nan_error:
#     156     # Improve the error message on how to handle missing values in
#     157     # scikit-learn.
#     158     msg_err += (
#     159         f"\n{estimator_name} does not accept missing values"
#     160         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     170         "#estimators-that-handle-nan-values"
#     171     )
# --> 172 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LinearRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()
forest.fit(x_train_s,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test_s,y_test)
# Out:
# 0.7905641638630108

# %%
from sklearn.model_selection import GridSearchCV
forest=RandomForestRegressor()
param_grid={
    "n_estimators":[100,200,300],
    "min_samples_split":[2,4],
    "max_depth":[None,4,8]
}
grid_search=GridSearchCV(forest,param_grid,cv=5,
                         scoring="neg_mean_squared_error",
                         return_train_score=True)
grid_search.fit(x_train_s,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(min_samples_split=4, n_estimators=300)

# %% [markdown]
# grid_search.best_estimator_.score(x_test_s,y_test)

# %%
grid_search.best_estimator_.score(x_test_s,y_test)
# Out:
# 0.7919851732671157
